# %%
import numpy as np
import pandas as pd
import ast

# %%
anime = pd.read_csv("animes.csv")

# %%
anime.head()
# Out:
#      uid                             title  \
# 0  28891           Haikyuu!! Second Season
# 1  23273           Shigatsu wa Kimi no Uso
# 2  34599                     Made in Abyss
# 3   5114  Fullmetal Alchemist: Brotherhood
# 4  31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
# 2   Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0   8.83
# 3    Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0   9.23
# 4                   Jan 6, 2017       1.0   214621         502    22.0   8.83
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/3/671...
# 2  https://cdn.myanimelist.net/images/anime/6/867...
# 3  https://cdn.myanimelist.net/images/anime/1223/...
# 4  https://cdn.myanimelist.net/images/anime/3/815...
#
#                                                 link
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1  https://myanimelist.net/anime/23273/Shigatsu_w...
# 2  https://myanimelist.net/anime/34599/Made_in_Abyss
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...
# 4  https://myanimelist.net/anime/31758/Kizumonoga...

# %%
anime.isna().mean()*100
anime.dropna(subset=['synopsis'], inplace=True)

anime.duplicated().sum()
anime.drop_duplicates(inplace=True)

# %%
anime = anime.reset_index(drop=True)
anime
# Out:
#          uid                                              title  \
# 0      28891                            Haikyuu!! Second Season
# 1      23273                            Shigatsu wa Kimi no Uso
# 2      34599                                      Made in Abyss
# 3       5114                   Fullmetal Alchemist: Brotherhood
# 4      31758                   Kizumonogatari III: Reiketsu-hen
# ...      ...                                                ...
# 15578  10075                                        Naruto x UT
# 15579  35828                                   Miira no Kaikata
# 15580  10378                             Shinryaku!? Ika Musume
# 15581  33082                      Kingsglaive: Final Fantasy XV
# 15582  16934  Chuunibyou demo Koi ga Shitai!: Kirameki no......
#
#                                                 synopsis  \
# 0      Following their participation at the Inter-Hig...
# 1      Music accompanies the path of the human metron...
# 2      The Abyss—a gaping chasm stretching down into ...
# 3      "In order for something to be obtained, someth...
# 4      After helping revive the legendary vampire Kis...
# ...                                                  ...
# 15578  All-new animation offered throughout UNIQLO cl...
# 15579  High school student Sora Kashiwagi is accustom...
# 15580  After regaining her squid-like abilities, Ika ...
# 15581  For years, the Niflheim Empire and the kingdom...
# 15582  Although Yuuta Togashi and Rikka Takanashi hav...
#
#                                                    genre  \
# 0      ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1      ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2      ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3      ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4       ['Action', 'Mystery', 'Supernatural', 'Vampire']
# ...                                                  ...
# 15578  ['Action', 'Comedy', 'Super Power', 'Martial A...
# 15579        ['Slice of Life', 'Comedy', 'Supernatural']
# 15580             ['Slice of Life', 'Comedy', 'Shounen']
# 15581                                         ['Action']
# 15582  ['Comedy', 'Drama', 'Romance', 'School', 'Slic...
#
#                               aired  episodes  members  popularity  ranked  \
# 0       Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0
# 1      Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0
# 2       Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0
# 3        Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0
# 4                       Jan 6, 2017       1.0   214621         502    22.0
# ...                             ...       ...      ...         ...     ...
# 15578                   Jan 1, 2011       1.0    34155        2382  1728.0
# 15579  Jan 12, 2018 to Mar 30, 2018      12.0    61459        1648  1727.0
# 15580  Sep 27, 2011 to Dec 25, 2011      12.0    67422        1547  1548.0
# 15581                   Jul 9, 2016       1.0    41077        2154  1544.0
# 15582                  Jun 19, 2013       1.0   128400         883  1533.0
#
#        score                                            img_url  \
# 0       8.82  https://cdn.myanimelist.net/images/anime/9/766...
# 1       8.83  https://cdn.myanimelist.net/images/anime/3/671...
# 2       8.83  https://cdn.myanimelist.net/images/anime/6/867...
# 3       9.23  https://cdn.myanimelist.net/images/anime/1223/...
# 4       8.83  https://cdn.myanimelist.net/images/anime/3/815...
# ...      ...                                                ...
# 15578   7.50  https://cdn.myanimelist.net/images/anime/3/304...
# 15579   7.50  https://cdn.myanimelist.net/images/anime/1486/...
# 15580   7.56  https://cdn.myanimelist.net/images/anime/6/301...
# 15581   7.56  https://cdn.myanimelist.net/images/anime/12/79...
# 15582   7.56  https://cdn.myanimelist.net/images/anime/7/455...
#
#                                                     link
# 0      https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1      https://myanimelist.net/anime/23273/Shigatsu_w...
# 2      https://myanimelist.net/anime/34599/Made_in_Abyss
# 3      https://myanimelist.net/anime/5114/Fullmetal_A...
# 4      https://myanimelist.net/anime/31758/Kizumonoga...
# ...                                                  ...
# 15578    https://myanimelist.net/anime/10075/Naruto_x_UT
# 15579  https://myanimelist.net/anime/35828/Miira_no_K...
# 15580  https://myanimelist.net/anime/10378/Shinryaku_...
# 15581  https://myanimelist.net/anime/33082/Kingsglaiv...
# 15582  https://myanimelist.net/anime/16934/Chuunibyou...
#
# [15583 rows x 12 columns]

# %%
anime = anime[['uid','title','genre','synopsis']]
anime = anime.map(lambda x: x.lower() if isinstance(x, str) else x)
anime['genre'] = anime['genre'].apply(lambda x: ast.literal_eval(x))

# %%
anime['synopsis'] = anime['synopsis'].apply(lambda x:x.split(' '))

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
anime['synopsis'] = anime['synopsis'].apply(collapse)
anime
# Out:
#          uid                                              title  \
# 0      28891                            haikyuu!! second season
# 1      23273                            shigatsu wa kimi no uso
# 2      34599                                      made in abyss
# 3       5114                   fullmetal alchemist: brotherhood
# 4      31758                   kizumonogatari iii: reiketsu-hen
# ...      ...                                                ...
# 15578  10075                                        naruto x ut
# 15579  35828                                   miira no kaikata
# 15580  10378                             shinryaku!? ika musume
# 15581  33082                      kingsglaive: final fantasy xv
# 15582  16934  chuunibyou demo koi ga shitai!: kirameki no......
#
#                                                    genre  \
# 0               [comedy, sports, drama, school, shounen]
# 1               [drama, music, romance, school, shounen]
# 2           [sci-fi, adventure, mystery, drama, fantasy]
# 3      [action, military, adventure, comedy, drama, m...
# 4               [action, mystery, supernatural, vampire]
# ...                                                  ...
# 15578  [action, comedy, super power, martial arts, sh...
# 15579              [slice of life, comedy, supernatural]
# 15580                   [slice of life, comedy, shounen]
# 15581                                           [action]
# 15582    [comedy, drama, romance, school, slice of life]
#
#                                                 synopsis
# 0      [following, their, participation, at, the, int...
# 1      [music, accompanies, the, path, of, the, human...
# 2      [the, abyss—a, gaping, chasm, stretching, down...
# 3      ["in, order, for, something, to, be, obtained,...
# 4      [after, helping, revive, the, legendary, vampi...
# ...                                                  ...
# 15578  [all-new, animation, offered, throughout, uniq...
# 15579  [high, school, student, sora, kashiwagi, is, a...
# 15580  [after, regaining, her, squid-like, abilities,...
# 15581  [for, years,, the, niflheim, empire, and, the,...
# 15582  [although, yuuta, togashi, and, rikka, takanas...
#
# [15583 rows x 4 columns]

# %%
anime['tags'] = anime['genre']+ anime['synopsis']
new_anime = anime.drop(columns=['genre','synopsis'])

# %%
new_anime['tags'] = new_anime['tags'].apply(lambda x: " ".join(x))
new_anime['tags']
# Out:
# 0        comedy sports drama school shounen following t...
# 1        drama music romance school shounen music accom...
# 2        sci-fi adventure mystery drama fantasy the aby...
# 3        action military adventure comedy drama magic f...
# 4        action mystery supernatural vampire after help...
#                                ...
# 15578    action comedy super power martial arts shounen...
# 15579    slice of life comedy supernatural high school ...
# 15580    slice of life comedy shounen after regaining h...
# 15581    action for years, the niflheim empire and the ...
# 15582    comedy drama romance school slice of life alth...
# Name: tags, Length: 15583, dtype: object

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()

def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_anime['tags'] = new_anime['tags'].apply(stem)

# %%
new_anime
# Out:
#          uid                                              title  \
# 0      28891                            haikyuu!! second season
# 1      23273                            shigatsu wa kimi no uso
# 2      34599                                      made in abyss
# 3       5114                   fullmetal alchemist: brotherhood
# 4      31758                   kizumonogatari iii: reiketsu-hen
# ...      ...                                                ...
# 15578  10075                                        naruto x ut
# 15579  35828                                   miira no kaikata
# 15580  10378                             shinryaku!? ika musume
# 15581  33082                      kingsglaive: final fantasy xv
# 15582  16934  chuunibyou demo koi ga shitai!: kirameki no......
#
#                                                     tags
# 0      comedi sport drama school shounen follow their...
# 1      drama music romanc school shounen music accomp...
# 2      sci-fi adventur mysteri drama fantasi the abys...
# 3      action militari adventur comedi drama magic fa...
# 4      action mysteri supernatur vampir after help re...
# ...                                                  ...
# 15578  action comedi super power martial art shounen ...
# 15579  slice of life comedi supernatur high school st...
# 15580  slice of life comedi shounen after regain her ...
# 15581  action for years, the niflheim empir and the k...
# 15582  comedi drama romanc school slice of life altho...
#
# [15583 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=6000,stop_words='english')

# %%
vector = cv.fit_transform(new_anime['tags']).toarray()

# %%
vector.shape
# Out:
# (15583, 6000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)
similarity
# Out:
# array([[1.        , 0.10679437, 0.07725291, ..., 0.08930886, 0.06362043,
#         0.07828751],
#        [0.10679437, 1.        , 0.12169009, ..., 0.08206381, 0.2922966 ,
#         0.07307841],
#        [0.07725291, 0.12169009, 1.        , ..., 0.04070628, 0.12324019,
#         0.0872247 ],
#        ...,
#        [0.08930886, 0.08206381, 0.04070628, ..., 1.        , 0.05237972,
#         0.12604604],
#        [0.06362043, 0.2922966 , 0.12324019, ..., 0.05237972, 1.        ,
#         0.03265116],
#        [0.07828751, 0.07307841, 0.0872247 , ..., 0.12604604, 0.03265116,
#         1.        ]])

# %%
def recommend(anime):
  ind =  new_anime[new_anime['title'] == anime].index[0]
  print(ind)
  distances = sorted(list(enumerate(similarity[ind])),reverse=True,key = lambda x: x[1])
  for i in distances[1:10]:
    print(new_anime.iloc[i[0]]['title'])

# %%
recommend('haikyuu!! second season')
# Out:
# 0
# haikyuu!!
# haikyuu!!: karasuno koukou vs. shiratorizawa gakuen koukou
# yowamushi pedal movie
# ashita e attack!
# midoriyama koukou koushien-hen
# shoujo fight: norainu-tachi no odekake
# ookiku furikabutte: natsu no taikai-hen
# kuroko no basket 2nd season
# diamond no ace: act ii
